# %%
import dl_weather

# For generating the geocontext:
from IPython import display as dsp
import shapely.geometry as sg
import descarteslabs as dl
import geojson

# For plotting timeseries:
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Create geoctx

# %%
# Get shape of state in Brazil
places_client = dl.Places()
state = places_client.shape("south-america_brazil_mato-grosso-do-sul")

# Define Workflows GeoContext
geoctx = dl.scenes.AOI(sg.shape(state.geometry).simplify(0.01),
                       crs="EPSG:4326", resolution=0.01)

# Display on a map:
dsp.GeoJSON(geojson.Feature(geometry=geoctx.geometry))

# %% [markdown]
# ---
# ---
# ## Run short unmasked timeseries:
# 1-month long, daily frequency
#
# ERA5: precipitation and zonal wind speed

# %%
# %%time
ts = dl_weather.get_weather_time_series(weather_product="ecmwf:era5:v0",
                                        weather_vars = ["tp",'100u'],
                                        weather_start = '2018-01-01',
                                        weather_end = '2018-02-01',
                                        frequency='daily',
                                        geoctx=geoctx)
ts.head()
# Out:
# Submitting 31 jobs
#   0%|          | 0/31 [00:00<?, ?it/s]
# CPU times: user 673 ms, sys: 80 ms, total: 753 ms
# Wall time: 1min 1s
#                   tp      100u
# 2018-01-01  0.006608  1.559266
# 2018-01-02  0.015886  2.760741
# 2018-01-03  0.005958  2.891965
# 2018-01-04  0.000628  0.074936
# 2018-01-05  0.005842 -0.130139

# %%
plt.figure(figsize=(8,6))
plt.subplot(2,1,1)
ts['tp'].plot(color='blue', label='Precipitation')
plt.grid('lightgray')
plt.legend()
plt.subplot(2,1,2) 
ts['100u'].plot(color='orange', label='Zonal wind speed')
plt.grid('lightgray')
plt.legend()
plt.tight_layout()

# %% [markdown]
# ---
# ---
# ## Run masked timeseries
# 1-year long, monthly frequency
#
# ERA5: precipitation and zonal wind speed

# %%
# %%time
ts = dl_weather.get_weather_time_series(weather_product="ecmwf:era5:v0",
                                        weather_vars = ["tp",'100u'],
                                        weather_start = '2015-01-01',
                                        weather_end = '2016-01-01',
                                        frequency='monthly',
                                        geoctx=geoctx,
                                        land_cover_product = "modis:mcd12q1:051",
                                        land_cover_bands = "Land_Cover_Type_1",
                                        land_cover_value = 12,
                                        land_cover_start = "2010-01-01",
                                        land_cover_end = "2011-01-01")
ts.head()
# Out:
# Submitting 12 jobs
#   0%|          | 0/12 [00:00<?, ?it/s]
# Retrieving monthly timeseries
#   0%|          | 0/12 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(8,6))
plt.subplot(2,1,1)
ts['tp'].plot(color='blue', label='Precipitation')
plt.grid('lightgray')
plt.legend()
plt.subplot(2,1,2)
ts['100u'].plot(color='orange', label='Zonal wind speed')
plt.grid('lightgray')
plt.legend()
plt.tight_layout()

# %% [markdown]
# ---
# ---
# ## Run masked timeseries
#
# 10-year long, monthly frequency
#
# ERA5: only precipitation

# %%
# %%time
ts = dl_weather.get_weather_time_series(weather_product="ecmwf:era5:v0",
                                        weather_vars = ["tp"],
                                        weather_start = '2005-01-01',
                                        weather_end = '2015-01-01',
                                        frequency='monthly',
                                        geoctx=geoctx,
                                        land_cover_product = "modis:mcd12q1:051",
                                        land_cover_bands = "Land_Cover_Type_1",
                                        land_cover_value = 12,
                                        land_cover_start = "2010-01-01",
                                        land_cover_end = "2011-01-01")
ts.head()
# Out:
# Submitting 120 jobs
#   0%|          | 0/120 [00:00<?, ?it/s]
# Retrieving monthly timeseries
#   0%|          | 0/120 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /opt/conda/lib/python3.7/site-packages/dl_weather/utils.py in get_weather_time_series(geoctx, weather_product, weather_vars, weather_start, weather_end, land_cover_product, land_cover_bands, land_cover_value, land_cover_start, land_cover_end, frequency, retry)
#     324             print("\nRetrieving monthly timeseries")
#     325             weather_means_ = [None] * len(jobs)
# --> 326             weather_means, errors = compute_retrieval(jobs, job_key, weather_means_)
#     327
#     328             # Retry failed jobs:
#
# /opt/conda/lib/python3.7/site-packages/dl_weather/utils.py in compute_retrieval(jobs, job_key, weather_means_)
#     308                 errors = {}
#     309
# --> 310                 for job in tqdm.tqdm(as_completed(jobs), total=len(jobs)):
#     311                     if job.error is not None:
#     312                         # print(f'\nFailed to retrieve one value, with exception: \n\t"{job.error}"\n')
#
# /opt/conda/lib/python3.7/site-packages/tqdm/notebook.py in __iter__(self)
#     252     def __iter__(self):
#     253         try:
# --> 254             for obj in super(tqdm_notebook, self).__iter__():
#     255                 # return super(tqdm...) will not catch exception
#     256                 yield obj
#
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# /opt/conda/lib/python3.7/site-packages/dl_weather/utils.py in as_completed(jobs, interval_sec)
#      31             if not job.done:  # in case it's already loaded
#      32                 try:
# ---> 33                     job.refresh()
#      34                 except Exception:
#      35                     None
#
# /opt/conda/lib/python3.7/site-packages/descarteslabs/workflows/models/job.py in refresh(self)
#     239         """
#     240         message = self._client.api["GetJob"](
# --> 241             job_pb2.GetJobRequest(id=self.id), timeout=self._client.DEFAULT_TIMEOUT
#     242         )
#     243         self._message = message
#
# /opt/conda/lib/python3.7/site-packages/descarteslabs/client/grpc/client.py in wrapper(*args, **kwargs)
#     227
#     228             try:
# --> 229                 return retry(func)(*args, **kwargs)
#     230             except grpc.RpcError as e:
#     231                 raise from_grpc_error(e) from None
#
# /opt/conda/lib/python3.7/site-packages/descarteslabs/common/retry/retry.py in wrapper(*args, **kwargs)
#     107             )
#     108
# --> 109             return self._retry(target, delay_generator)
#     110
#     111         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/descarteslabs/common/retry/retry.py in _retry(self, func, delay_generator)
#     122
#     123             try:
# --> 124                 return func()
#     125             except Exception as e:
#     126                 self._handle_exception(e, previous_exceptions)
#
# /opt/conda/lib/python3.7/site-packages/grpc/_interceptor.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     219                                                  credentials=credentials,
#     220                                                  wait_for_ready=wait_for_ready,
# --> 221                                                  compression=compression)
#     222         return response
#     223
#
# /opt/conda/lib/python3.7/site-packages/grpc/_interceptor.py in _with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     254         call = self._interceptor.intercept_unary_unary(continuation,
#     255                                                        client_call_details,
# --> 256                                                        request)
#     257         return call.result(), call
#     258
#
# /opt/conda/lib/python3.7/site-packages/descarteslabs/workflows/client/client.py in intercept_unary_unary(self, continuation, client_call_details, request)
#      99
#     100     def intercept_unary_unary(self, continuation, client_call_details, request):
# --> 101         return _log_warnings_postprocess(continuation(client_call_details, request))
#     102
#     103
#
# /opt/conda/lib/python3.7/site-packages/grpc/_interceptor.py in continuation(new_details, request)
#     245                     credentials=new_credentials,
#     246                     wait_for_ready=new_wait_for_ready,
# --> 247                     compression=new_compression)
#     248                 return _UnaryOutcome(response, call)
#     249             except grpc.RpcError as rpc_error:
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     931                   compression=None):
#     932         state, call, = self._blocking(request, timeout, metadata, credentials,
# --> 933                                       wait_for_ready, compression)
#     934         return _end_unary_response_blocking(state, call, True, None)
#     935
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in _blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     908                     None,
#     909                 ),), self._context)
# --> 910             event = call.next_event()
#     911             _handle_event(event, state, self._response_deserializer)
#     912             return state, call
#
# src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi in grpc._cython.cygrpc._next_call_event()
#
# src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi in grpc._cython.cygrpc._next_call_event()
#
# src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi in grpc._cython.cygrpc._metadatum()
#
# src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi in grpc._cython.cygrpc._interpret_event()
#
# src/python/grpcio/grpc/_cython/_cygrpc/tag.pyx.pxi in grpc._cython.cygrpc._BatchOperationTag.event()
#
# src/python/grpcio/grpc/_cython/_cygrpc/operation.pyx.pxi in grpc._cython.cygrpc.ReceiveInitialMetadataOperation.un_c()
#
# src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi in grpc._cython.cygrpc._metadata()
#
# src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi in genexpr()
#
# src/python/grpcio/grpc/_cython/_cygrpc/metadata.pyx.pxi in grpc._cython.cygrpc._metadatum()
#
# <string> in __new__(_cls, key, value)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(20,4))
ts['tp'].plot(color='blue', label='Precipitation')
plt.grid('lightgray')
plt.legend()
plt.tight_layout()
