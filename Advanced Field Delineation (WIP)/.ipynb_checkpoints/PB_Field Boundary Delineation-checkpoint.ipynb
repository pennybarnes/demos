# %% [markdown]
# # Data Exploration for Field Boundary Delineation

# %% [markdown]
# As summarized in `01_overview.ipynb` there are several datasets that are useful for field delineation that you have access to on the Descartes Labs platform. In this exercise we will be focusing on [Sentinel-2](https://catalog.descarteslabs.com/?/product/sentinel-2:L1C) and building a workflow that we can use for our field delineation model.
#
# We will use the following DL API's in this exercise:
# - [Workflows](https://docs.descarteslabs.com/guides/workflows.html#workflows-guide): For on-the-fly exploration of datasets and accessing ndarrays/imagery.
#
# We will use the following external Python packages:
# - [numpy](https://numpy.org/doc/stable/) - For manipulation of image data.
# - [matplotlib.pyplot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html) - For visualizing image and timeseries data.
# - [math](https://docs.python.org/3/library/math.html) - Used in computing utm zone EPSG codes in the `wgs_to_epsg()` function

# %%
import descarteslabs.workflows as wf
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def wgs_to_epsg(lat, lon):
    """
    Get the epsg code from a (lat, lon) location
    """
    utm_band = str((math.floor((lon + 180) / 6) % 60) + 1)
    if len(utm_band) == 1:
        utm_band = "0" + utm_band
    if lat >= 0:
        epsg_code = "326" + utm_band
    else:
        epsg_code = "327" + utm_band
    return epsg_code

# %% [markdown]
# ## Creating workflows image collections

# %% [markdown]
# We'll start by creating a workflows image collection for Sentinel-2. We will be focusing on one year of imagery (2019) for this exploration. More specifically we will be looking at imagery from around the growing season in our AOI.

# %%
year = 2020
start_datetime = f"{year}-05-01"
end_datetime = f"{year}-09-01"

# %%
ic = wf.ImageCollection.from_id(
    "sentinel-2:L1C",
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    processing_level="surface"
)
s1 = wf.ImageCollection.from_id(
    "sentinel-1:GRD",
    start_datetime=start_datetime,
    end_datetime=end_datetime,
)

# %% [markdown]
# ## Visualizing workflows image collections

# %% [markdown]
# Now let's look at the first image in the image collection using the workflows map and `.visualize()` method.

# %%
wf.map.center = [41.949161, -94.424215]

# %%
rgb = ic[0].pick_bands("red green blue")
rgb.visualize("Sentinel-2 RGB", scales=[[0, 0.4], [0, 0.4], [0, 0.4]])
s1_3_band = s1[0].pick_bands("vv vh vv")
s1_3_band.visualize("Sentinel-1 VV VH VV")

# %%
wf.map
# Out:
# `ipyleaflet` and/or `ipywidgets` Jupyter extensions are not installed! (or you're not in a Jupyter notebook.)
# To install for JupyterLab, run this in a cell:
#     !jupyter labextension install jupyter-leaflet @jupyter-widgets/jupyterlab-manager
# To install for plain Jupyter Notebook, run this in a cell:
#     !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Then, restart the kernel and refresh the webpage.

# %% [markdown]
# ----------

# %% [markdown]
# ------------

# %% [markdown]
# ## Examining the data more closely

# %% [markdown]
# Now that we have our Senintel-2 image collection let's pull the first few scenes locally to play with the data. We will be using the workflows map bounds to pull the data.

# %% [markdown]
# We'll center the map and fix the zoom level so we're all looking at the same imagery.

# %%
wf.map.center = [41.949161, -94.424215]
wf.map.zoom = 13

# %% [markdown]
# Now we can create a geocontext and access the imagery directly using the bounds of the map as a reference.

# %% [markdown]
# We specify the resolution of the geocontext using `resolution=desired_resolution`. We also grab the bounds of the workflow map and get the EPSG code corresponding to the UTM zone we are in.
#
# For reference we've included a table below of the native resolutions of the datasets discussed in `01_overview.ipynb`:
#
# --- | Sentinel-2 | Sentinel-1 | NAIP |
# --- | --- | --- | --- |
# Resolution (meters) | 10 | 15 | 1|

# %% [markdown]
# We grab the bounds of the workflows map using `wf.map.bounds`. We need to flatten and reorder these bounds to be compatible with the format required in a `wf.GeoContext`. The desired format is `(min_x, min_y, max_x, max_y)`

# %%
bounds_d = list(np.array(wf.map.bounds).flatten())
bounds = [bounds_d[1], bounds_d[0], bounds_d[3], bounds_d[2]]

# %%
utm_code = wgs_to_epsg(*wf.map.center)

# %%
ctx = wf.GeoContext(
    bounds=bounds,
    bounds_crs="EPSG:4326",
    crs=f"EPSG:{utm_code}",
    resolution = 10.
)

# %% [markdown]
# Now we can actually get the data from platform to work with locally. We do this with `.compute()` and the geocontext we just created. We'll start by accessing the first 10 scenes from our image collection.

# %%
result = ic[0:10].pick_bands("red green blue").compute(ctx)
# Out:
# Job ID: 15027d19f74c6f6a760e2323013d82fe69698bdfadd5d93d
# [######] | Steps: 40/40 | Stage: SUCCEEDED
# /opt/conda/lib/python3.7/site-packages/descarteslabs/workflows/models/job.py:368: FutureWarning: 'pyarrow.deserialize' is deprecated as of 2.0.0 and will be removed in a future version. Use pickle or the pyarrow IPC functionality instead.
#   return handler(self)

# %% [markdown]
# Now that we have the results lets dig into them. We get back various pieces of information from our `.compute()` call.

# %%
result
# Out:
# ImageCollectionResult of length 10:
#   * ndarray: MaskedArray<shape=(10, 3, 600, 1935), dtype=float64>
#   * properties: 10 items
#   * bandinfo: 'red', 'green', 'blue'
#   * geocontext: 'geometry', 'resolution', 'crs', 'bounds', ...

# %% [markdown]
# Our result has four primary pieces of information associated with it: `ndarray`, `properties`, `bandinfo`, and `geocontext`. `ndarray` is the actual image data stored in a `numpy.ndarray` object. `properties` contains a lot of useful information about the imagery you accessed. `bandinfo` is a dictionary of information about each band you requested. `geocontext` is the geocontext describing the data you accessed.

# %% [markdown]
# Let's look a the properties for one of the images we pulled in the Senintel-2 collection:

# %%
result.properties[0].keys()
# Out:
# dict_keys(['safe_id', 'opaque_fraction', 'acquired', 'cs_code', 'view_angle_1', 'azimuth_angle_1', 'proj4', 'bits_per_pixel', 'fill_fraction', 'raster_size', 'solar_azimuth_angle', 'archived', 'file_sizes', 'area', 'cloud_fraction_0', 'cirrus_fraction', 'absolute_orbit', 'cloud_fraction', 'reflectance_scale', 'azimuth_angle', 'files', 'sat_id', 'earth_sun_distance', 'solar_elevation_angle', 'relative_orbit', 'bright_fraction', 'descartes_version', 'view_angle', 'tile_id', 'degraded_fraction_0', 'sw_version', 'geotrans', 'projcs', 'bucket', 'file_md5s', 'processed', 'datastrip_id', 'owner_type', 'identifier', 'storage_state', 'modified', 'product', 'key', 'confidence_dlsr', 'geometry', 'id', 'crs', 'date'])

# %% [markdown]
# Let's also look at the shape of the underlying numpy ndarray.

# %%
print("Sentinel-2 IC shape:\t" + str(result.ndarray.shape))
# Out:
# Sentinel-2 IC shape:	(10, 3, 600, 1935)

# %% [markdown]
# The dimensions of the array correspond to `(time, bands, pixel_x, pixel_y)`.

# %% [markdown]
# ----------

# %% [markdown]
# **Exercise 2:** Using the Sentinel-1 image collection you created in Exercise 1 pull the first 10 images at 15 meter resolution. For each of these images print the acquisition date, pass direction, relative orbit, and scene id. Each of these properties can be useful when working with S1 imagery, especially pass direction and relative orbit. For more information on those two properties and how they relate to revisit rate see this [link](https://sentinel.esa.int/web/sentinel/user-guides/sentinel-1-sar/revisit-and-coverage).

# %%
result_s1 = s1[0:10].pick_bands("vv vh vv").compute(ctx)

for prop in result_s1.properties:
    date, img_pass, orbit, img_id = (
        prop["date"],
        prop["pass"],
        prop["relative_orbit"],
        prop["id"],
    )
    print(f"{date}, {img_pass}, {orbit}, {img_id} \n")
# Out:
# Job ID: b49ddd908962a695205dec474fa0875bfb2f8cfe1437bad8
# [######] | Steps: 120/120 | Stage: SUCCEEDED                                  2020-05-11T00:13:49.681040+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-05-11_063A1349_S1A
#
# 2020-05-23T00:13:50.467562+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-05-23_063A1350_S1A
#
# 2020-06-04T00:13:51.019418+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-06-04_063A1351_S1A
#
# 2020-06-16T00:13:51.912045+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-06-16_063A1351_S1A
#
# 2020-06-28T00:13:52.516713+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-06-28_063A1352_S1A
#
# 2020-07-10T00:13:53.198425+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-07-10_063A1353_S1A
#
# 2020-07-22T00:13:54.065892+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-07-22_063A1354_S1A
#
# 2020-08-03T00:13:54.756757+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-08-03_063A1354_S1A
#
# 2020-08-15T00:13:55.413828+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-08-15_063A1355_S1A
#
# 2020-08-27T00:13:56.232696+00:00, ASCENDING, 63, sentinel-1:GRD:meta_2020-08-27_063A1356_S1A
# /opt/conda/lib/python3.7/site-packages/descarteslabs/workflows/models/job.py:368: FutureWarning: 'pyarrow.deserialize' is deprecated as of 2.0.0 and will be removed in a future version. Use pickle or the pyarrow IPC functionality instead.
#   return handler(self)

# %% [markdown]
# ------------

# %% [markdown]
# ## Visualizing ndarray image data

# %% [markdown]
# Let's take a look at the three imagery sources. We can plot these images using `matplotlib.pyplot.imshow()`/

# %%
fig, ax = plt.subplots(1,1,figsize=(6,9))
# Plotting the image data
ax.imshow(np.moveaxis(result.ndarray[0], 0, -1))

# Turning the x and y labels off
ax.axis("off")

# Setting titles for each image
ax.set_title("S2 RGB (10m)")

fig.tight_layout()

# %% [markdown]
# We can once agagin see one of the primary drawbacks of using Sentinel-2 imagery. The scene we selected is very cloudy (not very useful for delineating a field). If we are in an AOI that we expect to be cloudly most of the time then Sentinel-1 GRD product will likely be more useful.

# %% [markdown]
# ## Refining our Sentinel-2 workflow

# %% [markdown]
# We will need to find a way to deal with cloudy scenes in our Sentinel-2 image collection. The best way to go about this is to construct a series of composites (in this case monthly) leveraging as many cloud free pixels as possible.

# %% [markdown]
# First let's filter out any overly cloudly scenes using the `cloud_fraction` property. To do this we can use the `.filter()` method of our image collection. We must provide a lambda function to specify what fraction of the total pixels being covered by clouds we are okay with having in our imagery (in this case < 10%).

# %%
ic_filtered = ic.filter(lambda img: img.properties["cloud_fraction"]<0.1)

# %% [markdown]
# To further refine the imagecollection we would like to mask out any remaining clouds in each image. To do this we can access a [cloud band](https://catalog.descarteslabs.com/?/product/sentinel-2:L1C/sentinel-2:L1C:cloud-mask) in the Sentinel-2 data and use this as a mask for our image collection. We mask an imagecollection with the `.mask()` method and a boolean layer.

# %%
cmask = ic_filtered.pick_bands("cloud-mask")
cmask = cmask > 0

# %%
ic_masked = ic_filtered.mask(cmask)

# %% [markdown]
# To try and deal with the "holes" the cloud masking will put in our images we should composite groups of images in the collection. We can group by a variety of properties but the one that makes the most sense for our application is by date. Let's try creating monthly composites. We want to also select our bands to minimize the amount of data we will be pulling when we run `.compute()`. We also want to take the mean composite over each group using `.mean()`. We can do all of this in one line as below:

# %%
monthly = ic_masked.groupby(lambda img: img.properties["date"].month).mean(axis="images")

# %%
result_rgb_monthly = monthly.pick_bands("red green blue").compute(ctx)
# Out:
# Job ID: b663f068c9e8d84ff38ac411801919a3b93c1c34016b5fba
# [######] | Steps: 294/294 | Stage: SUCCEEDED

# %% [markdown]
# We can now get the ndarray and look at it's shape. There should be 4 months in the date range we specified that correspond to the first dimension of the array.

# %%
monthly_arr = result_rgb_monthly.ndarray

# %%
monthly_arr.shape
# Out:
# (4, 3, 600, 1935)

# %% [markdown]
# Finally let's take a look at the monthly cloud free composites.

# %%
fig, axs = plt.subplots(4, 1, figsize=(9,12))
axs = axs.flatten()
for i in range(monthly_arr.shape[0]):
    axs[i].imshow(np.moveaxis(monthly_arr[i], 0, -1))
    axs[i].axis("off")
    axs[i].set_title("Month: " + str(result_rgb_monthly.properties[i]["group"]))

# %% [markdown]
# --------

# %% [markdown]
# **Exercise 3:** Make a set of monthly maximum composite of only "ASCENDING" passes for the Sentinel-1 image collection you used in Exercise 1 and 2. Plot those composites using the Sentinel-2 plots from above as reference. Use the "vv vh vv" band combination again here for visualization purposes.

# %%
s1_filtered = s1.filter(lambda img: img.properties["pass"] == "ASCENDING")
s1_monthly_max = s1_filtered.groupby(lambda img: img.properties["date"].month).max(
    axis="images"
)
s1_monthly_result = s1_monthly_max.pick_bands("vv vh vv").compute(ctx)

s1_monthly_arr = s1_monthly_result.ndarray

fig, axs = plt.subplots(4, 1, figsize=(9, 12))
axs = axs.flatten()
for i in range(s1_monthly_arr.shape[0]):
    axs[i].imshow(np.moveaxis(s1_monthly_arr[i], 0, -1))
    axs[i].axis("off")
    axs[i].set_title("Month: " + str(s1_monthly_result.properties[i]["group"]))
# Out:
# Job ID: 9bd782edf3771100ec087688bd19c11beff332e0905b04ea
# [######] | Steps: 168/168 | Stage: SUCCEEDED

# %% [markdown]
# -------------

# %% [markdown]
# ## Publishing our cloud free monthly workflow

# %% [markdown]
# Now let's save this workflow for the next notebook! We can do this using the `.publish()` method. You can find more information about this method [here](https://docs.descarteslabs.com/descarteslabs/workflows/docs/types/geospatial.html#descarteslabs.workflows.types.geospatial.ImageCollection.publish). You need to provide an id for your workflow of the form `'your@email.com:name_of_workflow'`. It can also only contain letters, numbers, and underscores. Once published we can access this workflow at any time without having to rerun this notebook!

# %%
my_email = "penny.barnes@descarteslabs.com"
version = "1.0.0"

monthly.publish(
    f"{my_email}:sentinel_2_monthly_cloudfree_rgb",
    version,
    title=f"Sentinel-2 RGB Monthly Cloud Free Composite ({start_datetime} to {end_datetime})"
)
# Out:
# Workflow: "Sentinel-2 RGB Monthly Cloud Free Composite (2020-05-01 to 2020-09-01)"
#     - id: penny.barnes@descarteslabs.com:sentinel_2_monthly_cloudfree_rgb
#     - labels: {}
#     - tags: []
#     - versions: '1.0.0'

# %% [markdown]
# We can view all of our published workflows with this handy built-in widget:

# %%
wf.interactive.WorkflowsBrowser()
# Out:
# WorkflowsBrowser(children=(HBox(children=(Button(icon='repeat', layout=Layout(overflow='visible', width='initi…
